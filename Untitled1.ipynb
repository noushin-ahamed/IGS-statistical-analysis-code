# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('NDVI_LST_HU.csv')

# %%
df.corr().round(3)
# Out:
# C:\Users\noush\AppData\Local\Temp\ipykernel_5888\352886112.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().round(3)
#        Year   NDVI    LST
# Year  1.000  0.518  0.154
# NDVI  0.518  1.000  0.360
# LST   0.154  0.360  1.000

# %%
sns.regplot(x="NDVI",
           y="LST",
           data=df)

plt.title(('Yearly NDVI vs LST Haut-Uele (2000-2020)'))
plt.show()

# %%
lat_mod = smf.ols("LST ~ NDVI", data=df).fit()
print (lat_mod.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    LST   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     2.828
# Date:                Thu, 30 Mar 2023   Prob (F-statistic):              0.109
# Time:                        05:45:27   Log-Likelihood:                 3.1947
# No. Observations:                  21   AIC:                            -2.389
# Df Residuals:                      19   BIC:                           -0.3003
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     17.8904      4.504      3.972      0.001       8.464      27.317
# ...

# %%
plt.hist(lat_mod.resid_pearson, 
         edgecolor='black',
         bins=[-2,-1.5,-1,-0.5,0,0.5,1,1.5,2])
plt.xlabel('Residuals')
# Out:
# Text(0.5, 0, 'Residuals')

# %%
plt.plot(lat_mod.fittedvalues, lat_mod.resid_pearson,
         'oC0',  
         markeredgecolor='black')
plt.axhline(c = 'red')
plt.xlabel('Predicted y Values')
plt.ylabel('Standardized Residuals (z)')
# Out:
# Text(0, 0.5, 'Standardized Residuals (z)')

# %%
qqfig = sm.qqplot(lat_mod.resid_pearson, line='r')

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(lat_mod, fig=fig)
# Out:
# eval_env: 1
# eval_env: 1

# %%
#BAS UELE

# %%
df2 = pd.read_csv('NDVI_LST_BU.csv')

# %%
df2.corr().round(3)
# Out:
# C:\Users\noush\AppData\Local\Temp\ipykernel_5888\1463618672.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr().round(3)
#        Year   NDVI    LST
# Year  1.000  0.709  0.080
# NDVI  0.709  1.000  0.301
# LST   0.080  0.301  1.000

# %%
sns.regplot(x="NDVI",
           y="LST",
           data=df2)

plt.title(('Yearly NDVI vs LST Bas-Uele (2000-2020)'))
plt.show()

# %%
lat_mod2 = smf.ols("LST ~ NDVI", data=df2).fit()
print (lat_mod2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    LST   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     1.892
# Date:                Thu, 30 Mar 2023   Prob (F-statistic):              0.185
# Time:                        05:49:21   Log-Likelihood:               -0.40834
# No. Observations:                  21   AIC:                             4.817
# Df Residuals:                      19   BIC:                             6.906
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     17.0965      6.487      2.636      0.016       3.519      30.674
# ...

# %%
plt.hist(lat_mod2.resid_pearson, 
         edgecolor='black',
         bins=[-2,-1.5,-1,-0.5,0,0.5,1,1.5,2])
plt.xlabel('Residuals')
# Out:
# Text(0.5, 0, 'Residuals')

# %%
plt.plot(lat_mod2.fittedvalues, lat_mod2.resid_pearson,
         'oC0',  
         markeredgecolor='black')
plt.axhline(c = 'red')
plt.xlabel('Predicted y Values')
plt.ylabel('Standardized Residuals (z)')
# Out:
# Text(0, 0.5, 'Standardized Residuals (z)')

# %%
qqfig = sm.qqplot(lat_mod2.resid_pearson, line='r')

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(lat_mod2, fig=fig)
# Out:
# eval_env: 1
# eval_env: 1

# %%
df3 = pd.read_csv('NDVI_LAST_I.csv')

# %%
sns.regplot(x="NDVI",
           y="LST",
           data=df3)

plt.title(('Yearly NDVI vs LST Ituri (2000-2020)'))
plt.show()

# %%
lat_mod3 = smf.ols("LST ~ NDVI", data=df3).fit()
print (lat_mod3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    LST   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.050
# Method:                 Least Squares   F-statistic:                   0.04134
# Date:                Thu, 30 Mar 2023   Prob (F-statistic):              0.841
# Time:                        05:59:26   Log-Likelihood:                -6.7019
# No. Observations:                  21   AIC:                             17.40
# Df Residuals:                      19   BIC:                             19.49
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.7907      4.520      5.264      0.000      14.331      33.250
# ...

# %%
plt.hist(lat_mod3.resid_pearson, 
         edgecolor='black',
         bins=[-2,-1.5,-1,-0.5,0,0.5,1,1.5,2])
plt.xlabel('Residuals')
# Out:
# Text(0.5, 0, 'Residuals')

# %%
plt.plot(lat_mod3.fittedvalues, lat_mod3.resid_pearson,
         'oC0',  
         markeredgecolor='black')
plt.axhline(c = 'red')
plt.xlabel('Predicted y Values')
plt.ylabel('Standardized Residuals (z)')
# Out:
# Text(0, 0.5, 'Standardized Residuals (z)')

# %%
qqfig = sm.qqplot(lat_mod3.resid_pearson, line='r')

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(lat_mod3, fig=fig)
# Out:
# eval_env: 1
# eval_env: 1
